# %%
import pandas as pd

df = pd.read_csv("./legal_instrument_index.csv", delimiter=";")

df.head()
# Out:
#    section_id  unesco_id                                      filename  \
# 0         201      15244      CONSTITUTION_0201_015244_1945_london.txt
# 1         201      49557         CONVENTION_0201_049557_2019_paris.txt
# 2         201      49523  CONVENTION_0201_049523_2019_buenos_aires.txt
# 3         201      49282   CONVENTION_0201_049282_2014_addis_ababa.txt
# 4         201      48975         CONVENTION_0201_048975_2011_tokyo.txt
#
#            type                                               href  year  \
# 0  CONSTITUTION  ev.php-URL_ID=15244&URL_DO=DO_TOPIC&URL_SECTIO...  1945
# 1    CONVENTION  ev.php-URL_ID=49557&URL_DO=DO_TOPIC&URL_SECTIO...  2019
# 2    CONVENTION  ev.php-URL_ID=49523&URL_DO=DO_TOPIC&URL_SECTIO...  2019
# 3    CONVENTION  ev.php-URL_ID=49282&URL_DO=DO_TOPIC&URL_SECTIO...  2014
# 4    CONVENTION  ev.php-URL_ID=48975&URL_DO=DO_TOPIC&URL_SECTIO...  2011
#
#          date          city                                            x.title
# ...

# %%
import csv

with open("./legal_instrument_index.csv", "r", encoding="utf-8") as f:
    sample = f.read(2048)
    dialect = csv.Sniffer().sniff(sample)
    print("Detected delimiter:", dialect.delimiter)
# Out:
# Detected delimiter: ;
